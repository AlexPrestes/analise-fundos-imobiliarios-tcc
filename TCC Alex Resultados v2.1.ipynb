# %%
import numpy as np
import pandas as pd
import xarray as xr
import urllib.request
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
#list_metricas = ['average_clustering', 'coefficient_distribution_degree', 'density', 'average_degree', 'average_short_path']#, 'number_of_nodes']
list_metricas = ['average_clustering', 'coefficient_distribution_degree', 'density', 'average_degree']

list_variables_a = [
    'Patrimonio_Liquido',
    'Cotas_Emitidas',
    'Valor_Patrimonial_Cotas',
    'Percentual_Rentabilidade_Efetiva_Mes',
    'Percentual_Rentabilidade_Patrimonial_Mes',
    'Percentual_Dividend_Yield_Mes',
    'Percentual_Amortizacao_Cotas_Mes',
]


list_variables_b = [
    'Valor_Ativo',
    'Percentual_Despesas_Taxa_Administracao',
    'Percentual_Despesas_Agente_Custodiante',
    'Total_Necessidades_Liquidez',
    'Disponibilidades',
    'Titulos_Publicos',
    'Titulos_Privados',
    'Fundos_Renda_Fixa',
    'Total_Investido',
    'Direitos_Bens_Imoveis',
    'Terrenos',
    'Imoveis_Renda_Acabados',
    'Imoveis_Renda_Construcao',
    'Imoveis_Venda_Acabados',
    'Imoveis_Venda_Construcao',
    'Outros_Direitos_Reais',
    'Acoes',
    'Debentures',
    'Bonus_Subscricao',
    'Certificados_Deposito_Valores_Mobiliarios',
    'Cedulas_Debentures',
    'Fundo_Acoes',
    'FIP',
    'FII',
    'FDIC',
    'Outras_Cotas_FI',
    'Notas_Promissorias',
    'Acoes_Sociedades_Atividades_FII',
    'Cotas_Sociedades_Atividades_FII',
    'CEPAC',
    'CRI',
    'Letras_Hipotecarias',
    'LCI',
    'LIG',
    'Outros_Valores_Mobliarios',
    'Valores_Receber',
    'Contas_Receber_Aluguel',
    'Contas_Receber_Venda_Imoveis',
    'Outros_Valores_Receber',
    'Rendimentos_Distribuir',
    'Taxa_Administracao_Pagar',
    'Taxa_Performance_Pagar',
    'Obrigacoes_Aquisicao_Imoveis',
    'Adiantamento_Venda_Imoveis',
    'Adiantamento_Alugueis',
    'Obrigacoes_Securitizacao_Recebiveis',
    'Instrumentos_Financeiros_Derivativos',
    'Provisoes_Contigencias',
    'Outros_Valores_Pagar',
    'Total_Passivo',
 ]

list_variables = list_variables_a + list_variables_b

list_cat = [
    'Mandato',
    'Segmento_Atuacao',
    #'Publico_Alvo',
    #'Tipo_Gestao',
]

ds_fii = xr.open_dataset('dataset/cvm/dataset_cvm_metrica_mensal.nc').fillna(0)
df_dados_fii = pd.read_csv('dataset/cvm/dataset_cvm_metrica_mensal_dados.csv', index_col='CNPJ_Fundo')

df_fii = ds_fii.to_array().stack(var=['variable', 'metrica']).to_pandas()

df_fii[['TIR']] = df_dados_fii[['TIR']][df_dados_fii[['TIR']].fillna(0).apply(zscore).abs() <= 1].fillna(0)
df_fii[[ (v, 'coefficient_distribution_degree') for v in list_variables ]] = df_fii[[ (v, 'coefficient_distribution_degree') for v in list_variables ]][df_fii[[ (v, 'coefficient_distribution_degree') for v in list_variables ]].apply(zscore).abs() <= 1].fillna(0)
df_fii_cat =  df_dados_fii[list_cat]


cnpj_meses = xr.open_dataset('dataset/cvm/dataset_cvm_metrica_mensal.nc').fillna(0).Acoes.sel(metrica='number_of_nodes').to_pandas()

# %%
def dataset_filter(df, lista_variaveis, lista_metricas, lista_cnpj):
    cols = [ (v, m) for v in lista_variaveis for m in lista_metricas ] + [ ('TIR', '') ]
    df_out = df[df.index.isin(lista_cnpj)][ cols ]
    
    return df_out.drop(columns=[ ('TIR', '') ]), df_out[ [ ('TIR', '') ] ]

# %%
def select_cols(df_fii, numbers, corr_val = 0.5, list_cat = []):
    grupos_fiis = df_dados_fii[list_cat].dropna().agg('-'.join, axis=1)

    set_cols = set()

    for grupo in np.unique(grupos_fiis.values):
        cnpj_grupo = grupos_fiis[grupos_fiis==grupo].index.values


        df_dados = df_fii[df_fii.index.isin(cnpj_grupo)]
        corr = df_dados.corr()
        cols = corr['TIR'][corr['TIR'].abs() >= corr_val].abs().sort_values(ascending=False).index.values[1:(numbers+1)]

        for t in cols:
            set_cols.add(t)

    set_cols.discard(('TIR', ''))
    return list(set_cols)

# %%
import copy

import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Resultado 1
#
# Gráfico por classificação

# %%
def model(X, y):
    from sklearn.ensemble import GradientBoostingRegressor
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.metrics import mean_absolute_error
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=2/3)
    
    best_score_train = np.inf
    best_score_test = np.inf
    best_weights = None
    
    for i in range(5, 6):
        model_train = RandomForestRegressor(n_estimators=i*100, n_jobs=-1)
        model_train.fit(X_train, y_train)

        y_pred = model_train.predict(X_train)
        score_train = mean_absolute_error(y_train, y_pred)
        error_train = list(y_train-y_pred)

        y_pred = model_train.predict(X_test)
        score_test = mean_absolute_error(y_test, y_pred)
        error_test = list(y_test-y_pred)

        if score_test < best_score_test:
            best_score_test = score_test
            best_score_train = score_train
            best_error_test = error_test
            best_error_train = error_train
            best_feature_importances = model_train.feature_importances_
    
    print(f'Score = (train: {best_score_train:.3f}, test: {best_score_test:.3f})')
    return best_score_train, best_score_test, best_feature_importances, best_error_train, best_error_test

# %%
tamanho_series = 12

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_12 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 28---
#   --- Sem classificação
# Score = (train: 22.684, test: 35.344)
# Score = (train: 0.374, test: 53.415)
# Score = (train: 19.593, test: 36.734)
# Score = (train: 18.319, test: 10.732)
# Score = (train: 24.482, test: 17.558)
#   --- Com classificação
# Score = (train: 1.234, test: 51.157)
# Score = (train: 22.911, test: 62.445)
# Score = (train: 20.003, test: 10.957)
# Score = (train: 24.576, test: 28.429)
# Score = (train: 0.375, test: 53.631)
# ---2: 52---
#   --- Sem classificação
# Score = (train: 22.026, test: 72.017)
# Score = (train: 21.997, test: 53.800)
# Score = (train: 26.898, test: 6.704)
# Score = (train: 25.513, test: 25.855)
# Score = (train: 22.012, test: 40.566)
#   --- Com classificação
# Score = (train: 1.001, test: 52.282)
# Score = (train: 1.328, test: 51.945)
# Score = (train: 22.685, test: 23.926)
# Score = (train: 24.094, test: 21.213)
# Score = (train: 21.591, test: 32.537)
# ---3: 70---
#   --- Sem classificação
# Score = (train: 1.616, test: 52.091)
# Score = (train: 27.309, test: 26.643)
# Score = (train: 0.202, test: 53.721)
# Score = (train: 24.477, test: 26.501)
# Score = (train: 26.617, test: 28.209)
#   --- Com classificação
# Score = (train: 0.386, test: 53.797)
# Score = (train: 24.986, test: 42.240)
# Score = (train: 0.355, test: 53.490)
# Score = (train: 20.388, test: 55.095)
# Score = (train: 1.464, test: 51.663)
# ---4: 84---
#   --- Sem classificação
# Score = (train: 0.447, test: 53.559)
# Score = (train: 27.169, test: 14.235)
# Score = (train: 24.000, test: 40.683)
# Score = (train: 25.965, test: 65.406)
# Score = (train: 1.755, test: 52.226)
#   --- Com classificação
# Score = (train: 26.498, test: 33.295)
# Score = (train: 27.443, test: 15.222)
# Score = (train: 26.184, test: 38.637)
# Score = (train: 24.690, test: 56.790)
# Score = (train: 26.484, test: 28.361)
# ---5: 96---
#   --- Sem classificação
# Score = (train: 24.922, test: 45.094)
# Score = (train: 25.249, test: 53.516)
# Score = (train: 1.265, test: 52.685)
# Score = (train: 25.007, test: 43.288)
# Score = (train: 28.264, test: 38.312)
#   --- Com classificação
# Score = (train: 26.614, test: 77.491)
# Score = (train: 1.207, test: 51.953)
# Score = (train: 0.967, test: 54.362)
# Score = (train: 0.377, test: 53.619)
# Score = (train: 0.473, test: 53.841)
# ---6: 105---
#   --- Sem classificação
# Score = (train: 24.595, test: 33.023)
# Score = (train: 23.960, test: 80.617)
# Score = (train: 27.472, test: 31.135)
# Score = (train: 0.428, test: 53.526)
# Score = (train: 26.496, test: 20.438)
#   --- Com classificação
# Score = (train: 1.401, test: 51.678)
# Score = (train: 1.079, test: 52.939)
# Score = (train: 25.593, test: 48.144)
# Score = (train: 0.171, test: 53.801)
# Score = (train: 28.991, test: 43.271)
# ---7: 109---
#   --- Sem classificação
# Score = (train: 25.147, test: 73.022)
# Score = (train: 27.726, test: 20.673)
# Score = (train: 23.715, test: 75.692)
# Score = (train: 31.976, test: 55.869)
# Score = (train: 27.944, test: 34.858)
#   --- Com classificação
# Score = (train: 0.493, test: 53.040)
# Score = (train: 27.167, test: 35.589)
# Score = (train: 26.962, test: 25.808)
# Score = (train: 25.099, test: 55.361)
# Score = (train: 1.336, test: 51.498)
# ---8: 118---
#   --- Sem classificação
# Score = (train: 0.122, test: 53.845)
# Score = (train: 28.410, test: 30.489)
# Score = (train: 0.221, test: 53.509)
# Score = (train: 23.132, test: 36.733)
# Score = (train: 0.323, test: 54.095)
#   --- Com classificação
# Score = (train: 26.400, test: 43.708)
# Score = (train: 1.220, test: 52.213)
# Score = (train: 30.772, test: 32.165)
# Score = (train: 29.638, test: 37.230)
# Score = (train: 26.887, test: 41.276)
# ---9: 128---
#   --- Sem classificação
# Score = (train: 25.616, test: 30.656)
# Score = (train: 0.313, test: 53.742)
# Score = (train: 26.249, test: 32.365)
# Score = (train: 1.293, test: 52.733)
# Score = (train: 25.389, test: 57.839)
#   --- Com classificação
# Score = (train: 25.584, test: 26.511)
# Score = (train: 25.708, test: 52.873)
# Score = (train: 26.103, test: 25.999)
# Score = (train: 27.652, test: 44.022)
# Score = (train: 28.123, test: 61.089)
# ---10: 135---
#   --- Sem classificação
# Score = (train: 25.682, test: 77.403)
# Score = (train: 27.933, test: 55.148)
# Score = (train: 1.497, test: 53.026)
# Score = (train: 27.198, test: 54.366)
# Score = (train: 22.379, test: 68.289)
#   --- Com classificação
# Score = (train: 1.212, test: 53.008)
# Score = (train: 0.431, test: 53.309)
# Score = (train: 20.493, test: 84.534)
# Score = (train: 29.667, test: 19.919)
# Score = (train: 27.073, test: 68.126)

# %%
tamanho_series = 24

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_24 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 24---
#   --- Sem classificação
# Score = (train: 0.296, test: 0.522)
# Score = (train: 0.084, test: 0.682)
# Score = (train: 0.305, test: 0.399)
# Score = (train: 0.246, test: 0.366)
# Score = (train: 0.281, test: 0.692)
#   --- Com classificação
# Score = (train: 0.261, test: 0.662)
# Score = (train: 0.300, test: 0.468)
# Score = (train: 0.242, test: 0.569)
# Score = (train: 0.265, test: 0.690)
# Score = (train: 0.285, test: 0.537)
# ---2: 45---
#   --- Sem classificação
# Score = (train: 0.152, test: 0.618)
# Score = (train: 0.314, test: 0.518)
# Score = (train: 0.084, test: 0.662)
# Score = (train: 0.073, test: 0.697)
# Score = (train: 0.077, test: 0.687)
#   --- Com classificação
# Score = (train: 0.299, test: 0.493)
# Score = (train: 0.090, test: 0.640)
# Score = (train: 0.155, test: 0.616)
# Score = (train: 0.304, test: 0.426)
# Score = (train: 0.138, test: 0.601)
# ---3: 62---
#   --- Sem classificação
# Score = (train: 0.153, test: 0.610)
# Score = (train: 0.298, test: 0.502)
# Score = (train: 0.261, test: 0.829)
# Score = (train: 0.320, test: 0.487)
# Score = (train: 0.241, test: 0.645)
#   --- Com classificação
# Score = (train: 0.295, test: 0.596)
# Score = (train: 0.068, test: 0.678)
# Score = (train: 0.336, test: 0.642)
# Score = (train: 0.323, test: 0.501)
# Score = (train: 0.265, test: 0.481)
# ---4: 77---
#   --- Sem classificação
# Score = (train: 0.144, test: 0.766)
# Score = (train: 0.304, test: 0.546)
# Score = (train: 0.208, test: 0.661)
# Score = (train: 0.301, test: 0.507)
# Score = (train: 0.277, test: 0.440)
#   --- Com classificação
# Score = (train: 0.198, test: 0.781)
# Score = (train: 0.324, test: 0.558)
# Score = (train: 0.136, test: 0.702)
# Score = (train: 0.139, test: 0.746)
# Score = (train: 0.086, test: 0.651)
# ---5: 91---
#   --- Sem classificação
# Score = (train: 0.277, test: 0.834)
# Score = (train: 0.078, test: 0.687)
# Score = (train: 0.299, test: 0.669)
# Score = (train: 0.301, test: 0.531)
# Score = (train: 0.084, test: 0.647)
#   --- Com classificação
# Score = (train: 0.077, test: 0.694)
# Score = (train: 0.070, test: 0.711)
# Score = (train: 0.133, test: 0.660)
# Score = (train: 0.144, test: 0.821)
# Score = (train: 0.205, test: 0.670)
# ---6: 102---
#   --- Sem classificação
# Score = (train: 0.145, test: 0.691)
# Score = (train: 0.256, test: 0.592)
# Score = (train: 0.267, test: 0.587)
# Score = (train: 0.268, test: 0.632)
# Score = (train: 0.303, test: 0.493)
#   --- Com classificação
# Score = (train: 0.070, test: 0.692)
# Score = (train: 0.157, test: 0.724)
# Score = (train: 0.312, test: 0.765)
# Score = (train: 0.150, test: 0.545)
# Score = (train: 0.157, test: 0.631)
# ---7: 111---
#   --- Sem classificação
# Score = (train: 0.298, test: 0.638)
# Score = (train: 0.319, test: 0.606)
# Score = (train: 0.288, test: 0.799)
# Score = (train: 0.077, test: 0.679)
# Score = (train: 0.255, test: 0.768)
#   --- Com classificação
# Score = (train: 0.227, test: 0.535)
# Score = (train: 0.316, test: 0.423)
# Score = (train: 0.246, test: 0.441)
# Score = (train: 0.281, test: 0.487)
# Score = (train: 0.265, test: 0.762)
# ---8: 117---
#   --- Sem classificação
# Score = (train: 0.135, test: 0.659)
# Score = (train: 0.086, test: 0.636)
# Score = (train: 0.301, test: 0.554)
# Score = (train: 0.235, test: 0.918)
# Score = (train: 0.256, test: 0.371)
#   --- Com classificação
# Score = (train: 0.183, test: 1.108)
# Score = (train: 0.279, test: 0.709)
# Score = (train: 0.137, test: 0.719)
# Score = (train: 0.260, test: 0.559)
# Score = (train: 0.315, test: 0.496)
# ---9: 124---
#   --- Sem classificação
# Score = (train: 0.140, test: 0.618)
# Score = (train: 0.341, test: 0.369)
# Score = (train: 0.325, test: 0.547)
# Score = (train: 0.265, test: 0.626)
# Score = (train: 0.332, test: 0.579)
#   --- Com classificação
# Score = (train: 0.323, test: 0.512)
# Score = (train: 0.219, test: 0.651)
# Score = (train: 0.316, test: 0.444)
# Score = (train: 0.199, test: 0.632)
# Score = (train: 0.074, test: 0.686)
# ---10: 126---
#   --- Sem classificação
# Score = (train: 0.150, test: 0.620)
# Score = (train: 0.318, test: 0.420)
# Score = (train: 0.271, test: 0.409)
# Score = (train: 0.076, test: 0.703)
# Score = (train: 0.306, test: 0.626)
#   --- Com classificação
# Score = (train: 0.331, test: 0.708)
# Score = (train: 0.332, test: 0.648)
# Score = (train: 0.149, test: 0.639)
# Score = (train: 0.318, test: 0.484)
# Score = (train: 0.156, test: 0.641)

# %%
tamanho_series = 36

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_36 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 18---
#   --- Sem classificação
# Score = (train: 0.073, test: 0.390)
# Score = (train: 0.091, test: 0.361)
# Score = (train: 0.139, test: 0.356)
# Score = (train: 0.078, test: 0.388)
# Score = (train: 0.156, test: 0.225)
#   --- Com classificação
# Score = (train: 0.150, test: 0.311)
# Score = (train: 0.135, test: 0.405)
# Score = (train: 0.129, test: 0.315)
# Score = (train: 0.131, test: 0.530)
# Score = (train: 0.146, test: 0.251)
# ---2: 29---
#   --- Sem classificação
# Score = (train: 0.078, test: 0.395)
# Score = (train: 0.148, test: 0.247)
# Score = (train: 0.077, test: 0.418)
# Score = (train: 0.155, test: 0.284)
# Score = (train: 0.148, test: 0.295)
#   --- Com classificação
# Score = (train: 0.147, test: 0.281)
# Score = (train: 0.153, test: 0.327)
# Score = (train: 0.083, test: 0.375)
# Score = (train: 0.086, test: 0.368)
# Score = (train: 0.134, test: 0.290)
# ---3: 43---
#   --- Sem classificação
# Score = (train: 0.162, test: 0.177)
# Score = (train: 0.147, test: 0.493)
# Score = (train: 0.088, test: 0.315)
# Score = (train: 0.158, test: 0.303)
# Score = (train: 0.155, test: 0.432)
#   --- Com classificação
# Score = (train: 0.071, test: 0.381)
# Score = (train: 0.063, test: 0.378)
# Score = (train: 0.150, test: 0.280)
# Score = (train: 0.071, test: 0.377)
# Score = (train: 0.164, test: 0.265)
# ---4: 57---
#   --- Sem classificação
# Score = (train: 0.079, test: 0.358)
# Score = (train: 0.081, test: 0.391)
# Score = (train: 0.156, test: 0.313)
# Score = (train: 0.163, test: 0.248)
# Score = (train: 0.157, test: 0.213)
#   --- Com classificação
# Score = (train: 0.141, test: 0.304)
# Score = (train: 0.067, test: 0.399)
# Score = (train: 0.150, test: 0.509)
# Score = (train: 0.146, test: 0.507)
# Score = (train: 0.145, test: 0.417)
# ---5: 71---
#   --- Sem classificação
# Score = (train: 0.146, test: 0.424)
# Score = (train: 0.177, test: 0.344)
# Score = (train: 0.072, test: 0.376)
# Score = (train: 0.158, test: 0.378)
# Score = (train: 0.173, test: 0.317)
#   --- Com classificação
# Score = (train: 0.095, test: 0.335)
# Score = (train: 0.165, test: 0.354)
# Score = (train: 0.143, test: 0.587)
# Score = (train: 0.065, test: 0.390)
# Score = (train: 0.155, test: 0.367)
# ---6: 81---
#   --- Sem classificação
# Score = (train: 0.171, test: 0.417)
# Score = (train: 0.160, test: 0.370)
# Score = (train: 0.070, test: 0.377)
# Score = (train: 0.166, test: 0.465)
# Score = (train: 0.082, test: 0.361)
#   --- Com classificação
# Score = (train: 0.164, test: 0.289)
# Score = (train: 0.153, test: 0.631)
# Score = (train: 0.070, test: 0.392)
# Score = (train: 0.069, test: 0.406)
# Score = (train: 0.166, test: 0.343)
# ---7: 91---
#   --- Sem classificação
# Score = (train: 0.167, test: 0.292)
# Score = (train: 0.158, test: 0.329)
# Score = (train: 0.159, test: 0.396)
# Score = (train: 0.148, test: 0.278)
# Score = (train: 0.173, test: 0.420)
#   --- Com classificação
# Score = (train: 0.077, test: 0.390)
# Score = (train: 0.167, test: 0.290)
# Score = (train: 0.072, test: 0.410)
# Score = (train: 0.144, test: 0.322)
# Score = (train: 0.081, test: 0.383)
# ---8: 100---
#   --- Sem classificação
# Score = (train: 0.152, test: 0.368)
# Score = (train: 0.186, test: 0.218)
# Score = (train: 0.177, test: 0.391)
# Score = (train: 0.160, test: 0.304)
# Score = (train: 0.153, test: 0.403)
#   --- Com classificação
# Score = (train: 0.163, test: 0.368)
# Score = (train: 0.142, test: 0.395)
# Score = (train: 0.144, test: 0.656)
# Score = (train: 0.077, test: 0.392)
# Score = (train: 0.141, test: 0.616)
# ---9: 106---
#   --- Sem classificação
# Score = (train: 0.158, test: 0.285)
# Score = (train: 0.166, test: 0.355)
# Score = (train: 0.170, test: 0.453)
# Score = (train: 0.153, test: 0.353)
# Score = (train: 0.149, test: 0.466)
#   --- Com classificação
# Score = (train: 0.071, test: 0.394)
# Score = (train: 0.127, test: 0.924)
# Score = (train: 0.075, test: 0.375)
# Score = (train: 0.173, test: 0.251)
# Score = (train: 0.062, test: 0.387)
# ---10: 115---
#   --- Sem classificação
# Score = (train: 0.159, test: 0.459)
# Score = (train: 0.076, test: 0.362)
# Score = (train: 0.152, test: 0.528)
# Score = (train: 0.080, test: 0.362)
# Score = (train: 0.180, test: 0.317)
#   --- Com classificação
# Score = (train: 0.066, test: 0.398)
# Score = (train: 0.081, test: 0.351)
# Score = (train: 0.079, test: 0.352)
# Score = (train: 0.077, test: 0.369)
# Score = (train: 0.170, test: 0.372)

# %%
tamanho_series = 48

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_48 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 19---
#   --- Sem classificação
# Score = (train: 0.171, test: 0.305)
# Score = (train: 0.171, test: 0.407)
# Score = (train: 0.182, test: 0.252)
# Score = (train: 0.075, test: 0.427)
# Score = (train: 0.135, test: 0.404)
#   --- Com classificação
# Score = (train: 0.160, test: 0.204)
# Score = (train: 0.073, test: 0.408)
# Score = (train: 0.074, test: 0.402)
# Score = (train: 0.080, test: 0.381)
# Score = (train: 0.055, test: 0.461)
# ---2: 32---
#   --- Sem classificação
# Score = (train: 0.146, test: 0.267)
# Score = (train: 0.150, test: 0.288)
# Score = (train: 0.175, test: 0.271)
# Score = (train: 0.068, test: 0.425)
# Score = (train: 0.153, test: 0.374)
#   --- Com classificação
# Score = (train: 0.165, test: 0.187)
# Score = (train: 0.166, test: 0.212)
# Score = (train: 0.167, test: 0.378)
# Score = (train: 0.164, test: 0.303)
# Score = (train: 0.167, test: 0.253)
# ---3: 45---
#   --- Sem classificação
# Score = (train: 0.169, test: 0.232)
# Score = (train: 0.166, test: 0.288)
# Score = (train: 0.063, test: 0.447)
# Score = (train: 0.151, test: 0.315)
# Score = (train: 0.169, test: 0.257)
#   --- Com classificação
# Score = (train: 0.167, test: 0.368)
# Score = (train: 0.171, test: 0.318)
# Score = (train: 0.069, test: 0.421)
# Score = (train: 0.182, test: 0.313)
# Score = (train: 0.166, test: 0.439)
# ---4: 59---
#   --- Sem classificação
# Score = (train: 0.177, test: 0.380)
# Score = (train: 0.159, test: 0.448)
# Score = (train: 0.164, test: 0.360)
# Score = (train: 0.063, test: 0.442)
# Score = (train: 0.059, test: 0.452)
#   --- Com classificação
# Score = (train: 0.179, test: 0.530)
# Score = (train: 0.157, test: 0.585)
# Score = (train: 0.081, test: 0.368)
# Score = (train: 0.061, test: 0.415)
# Score = (train: 0.181, test: 0.344)
# ---5: 66---
#   --- Sem classificação
# Score = (train: 0.191, test: 0.484)
# Score = (train: 0.078, test: 0.404)
# Score = (train: 0.182, test: 0.345)
# Score = (train: 0.075, test: 0.395)
# Score = (train: 0.168, test: 0.474)
#   --- Com classificação
# Score = (train: 0.064, test: 0.423)
# Score = (train: 0.068, test: 0.419)
# Score = (train: 0.071, test: 0.405)
# Score = (train: 0.192, test: 0.409)
# Score = (train: 0.171, test: 0.440)
# ---6: 77---
#   --- Sem classificação
# Score = (train: 0.166, test: 0.639)
# Score = (train: 0.162, test: 0.516)
# Score = (train: 0.174, test: 0.287)
# Score = (train: 0.072, test: 0.402)
# Score = (train: 0.178, test: 0.326)
#   --- Com classificação
# Score = (train: 0.189, test: 0.389)
# Score = (train: 0.080, test: 0.409)
# Score = (train: 0.186, test: 0.428)
# Score = (train: 0.074, test: 0.385)
# Score = (train: 0.174, test: 0.398)
# ---7: 89---
#   --- Sem classificação
# Score = (train: 0.196, test: 0.371)
# Score = (train: 0.183, test: 0.281)
# Score = (train: 0.198, test: 0.324)
# Score = (train: 0.066, test: 0.424)
# Score = (train: 0.082, test: 0.386)
#   --- Com classificação
# Score = (train: 0.185, test: 0.502)
# Score = (train: 0.060, test: 0.440)
# Score = (train: 0.078, test: 0.405)
# Score = (train: 0.077, test: 0.409)
# Score = (train: 0.198, test: 0.389)
# ---8: 98---
#   --- Sem classificação
# Score = (train: 0.077, test: 0.392)
# Score = (train: 0.069, test: 0.395)
# Score = (train: 0.187, test: 0.407)
# Score = (train: 0.062, test: 0.418)
# Score = (train: 0.071, test: 0.408)
#   --- Com classificação
# Score = (train: 0.198, test: 0.303)
# Score = (train: 0.174, test: 0.285)
# Score = (train: 0.069, test: 0.430)
# Score = (train: 0.179, test: 0.370)
# Score = (train: 0.077, test: 0.405)
# ---9: 106---
#   --- Sem classificação
# Score = (train: 0.192, test: 0.258)
# Score = (train: 0.200, test: 0.426)
# Score = (train: 0.071, test: 0.413)
# Score = (train: 0.056, test: 0.442)
# Score = (train: 0.191, test: 0.318)
#   --- Com classificação
# Score = (train: 0.206, test: 0.343)
# Score = (train: 0.191, test: 0.195)
# Score = (train: 0.188, test: 0.350)
# Score = (train: 0.189, test: 0.707)
# Score = (train: 0.175, test: 0.431)
# ---10: 112---
#   --- Sem classificação
# Score = (train: 0.082, test: 0.373)
# Score = (train: 0.188, test: 0.338)
# Score = (train: 0.198, test: 0.335)
# Score = (train: 0.074, test: 0.381)
# Score = (train: 0.192, test: 0.269)
#   --- Com classificação
# Score = (train: 0.157, test: 0.433)
# Score = (train: 0.075, test: 0.398)
# Score = (train: 0.182, test: 0.380)
# Score = (train: 0.085, test: 0.358)
# Score = (train: 0.178, test: 0.282)

# %%
tamanho_series = 60

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_60 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 19---
#   --- Sem classificação
# Score = (train: 0.056, test: 0.414)
# Score = (train: 0.246, test: 0.386)
# Score = (train: 0.053, test: 0.408)
# Score = (train: 0.052, test: 0.413)
# Score = (train: 0.218, test: 0.256)
#   --- Com classificação
# Score = (train: 0.249, test: 0.441)
# Score = (train: 0.045, test: 0.447)
# Score = (train: 0.244, test: 0.391)
# Score = (train: 0.218, test: 0.560)
# Score = (train: 0.214, test: 0.501)
# ---2: 35---
#   --- Sem classificação
# Score = (train: 0.217, test: 0.522)
# Score = (train: 0.047, test: 0.427)
# Score = (train: 0.229, test: 0.448)
# Score = (train: 0.255, test: 0.371)
# Score = (train: 0.249, test: 0.408)
#   --- Com classificação
# Score = (train: 0.056, test: 0.401)
# Score = (train: 0.232, test: 0.432)
# Score = (train: 0.233, test: 0.476)
# Score = (train: 0.236, test: 0.379)
# Score = (train: 0.237, test: 0.420)
# ---3: 50---
#   --- Sem classificação
# Score = (train: 0.044, test: 0.440)
# Score = (train: 0.201, test: 0.452)
# Score = (train: 0.199, test: 0.326)
# Score = (train: 0.197, test: 0.587)
# Score = (train: 0.215, test: 0.434)
#   --- Com classificação
# Score = (train: 0.217, test: 0.399)
# Score = (train: 0.197, test: 0.506)
# Score = (train: 0.047, test: 0.440)
# Score = (train: 0.199, test: 0.404)
# Score = (train: 0.202, test: 0.404)
# ---4: 62---
#   --- Sem classificação
# Score = (train: 0.050, test: 0.435)
# Score = (train: 0.155, test: 0.409)
# Score = (train: 0.175, test: 0.313)
# Score = (train: 0.049, test: 0.431)
# Score = (train: 0.047, test: 0.438)
#   --- Com classificação
# Score = (train: 0.169, test: 0.212)
# Score = (train: 0.173, test: 0.364)
# Score = (train: 0.176, test: 0.377)
# Score = (train: 0.150, test: 0.597)
# Score = (train: 0.052, test: 0.429)
# ---5: 73---
#   --- Sem classificação
# Score = (train: 0.191, test: 0.256)
# Score = (train: 0.059, test: 0.386)
# Score = (train: 0.194, test: 0.332)
# Score = (train: 0.184, test: 0.398)
# Score = (train: 0.178, test: 0.334)
#   --- Com classificação
# Score = (train: 0.044, test: 0.437)
# Score = (train: 0.174, test: 0.351)
# Score = (train: 0.059, test: 0.420)
# Score = (train: 0.166, test: 0.500)
# Score = (train: 0.060, test: 0.390)
# ---6: 81---
#   --- Sem classificação
# Score = (train: 0.168, test: 0.506)
# Score = (train: 0.205, test: 0.280)
# Score = (train: 0.201, test: 0.395)
# Score = (train: 0.212, test: 0.454)
# Score = (train: 0.197, test: 0.255)
#   --- Com classificação
# Score = (train: 0.209, test: 0.270)
# Score = (train: 0.201, test: 0.314)
# Score = (train: 0.145, test: 0.999)
# Score = (train: 0.061, test: 0.397)
# Score = (train: 0.057, test: 0.402)
# ---7: 88---
#   --- Sem classificação
# Score = (train: 0.199, test: 0.417)
# Score = (train: 0.046, test: 0.463)
# Score = (train: 0.205, test: 0.305)
# Score = (train: 0.185, test: 0.309)
# Score = (train: 0.202, test: 0.326)
#   --- Com classificação
# Score = (train: 0.059, test: 0.412)
# Score = (train: 0.201, test: 0.212)
# Score = (train: 0.205, test: 0.596)
# Score = (train: 0.050, test: 0.428)
# Score = (train: 0.203, test: 0.463)
# ---8: 96---
#   --- Sem classificação
# Score = (train: 0.195, test: 0.376)
# Score = (train: 0.055, test: 0.414)
# Score = (train: 0.158, test: 0.456)
# Score = (train: 0.163, test: 1.009)
# Score = (train: 0.192, test: 0.344)
#   --- Com classificação
# Score = (train: 0.056, test: 0.416)
# Score = (train: 0.205, test: 0.455)
# Score = (train: 0.194, test: 0.342)
# Score = (train: 0.054, test: 0.416)
# Score = (train: 0.216, test: 0.375)
# ---9: 101---
#   --- Sem classificação
# Score = (train: 0.052, test: 0.429)
# Score = (train: 0.178, test: 0.640)
# Score = (train: 0.193, test: 0.251)
# Score = (train: 0.050, test: 0.430)
# Score = (train: 0.055, test: 0.409)
#   --- Com classificação
# Score = (train: 0.203, test: 0.429)
# Score = (train: 0.213, test: 0.407)
# Score = (train: 0.184, test: 0.602)
# Score = (train: 0.053, test: 0.421)
# Score = (train: 0.054, test: 0.435)
# ---10: 106---
#   --- Sem classificação
# Score = (train: 0.052, test: 0.420)
# Score = (train: 0.209, test: 0.399)
# Score = (train: 0.162, test: 0.699)
# Score = (train: 0.059, test: 0.410)
# Score = (train: 0.198, test: 0.695)
#   --- Com classificação
# Score = (train: 0.180, test: 0.808)
# Score = (train: 0.202, test: 0.321)
# Score = (train: 0.196, test: 0.371)
# Score = (train: 0.054, test: 0.416)
# Score = (train: 0.212, test: 0.264)

# %%
tamanho_series = 72

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)

saida_dados_72 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 19---
#   --- Sem classificação
# Score = (train: 0.249, test: 0.346)
# Score = (train: 0.051, test: 0.480)
# Score = (train: 0.211, test: 0.405)
# Score = (train: 0.239, test: 0.407)
# Score = (train: 0.051, test: 0.483)
#   --- Com classificação
# Score = (train: 0.266, test: 0.408)
# Score = (train: 0.055, test: 0.491)
# Score = (train: 0.046, test: 0.497)
# Score = (train: 0.057, test: 0.465)
# Score = (train: 0.224, test: 0.731)
# ---2: 33---
#   --- Sem classificação
# Score = (train: 0.057, test: 0.462)
# Score = (train: 0.214, test: 0.320)
# Score = (train: 0.053, test: 0.492)
# Score = (train: 0.048, test: 0.490)
# Score = (train: 0.225, test: 0.185)
#   --- Com classificação
# Score = (train: 0.049, test: 0.505)
# Score = (train: 0.183, test: 0.415)
# Score = (train: 0.200, test: 0.449)
# Score = (train: 0.194, test: 0.545)
# Score = (train: 0.189, test: 0.553)
# ---3: 43---
#   --- Sem classificação
# Score = (train: 0.052, test: 0.480)
# Score = (train: 0.246, test: 0.316)
# Score = (train: 0.200, test: 0.402)
# Score = (train: 0.241, test: 0.380)
# Score = (train: 0.215, test: 0.344)
#   --- Com classificação
# Score = (train: 0.049, test: 0.484)
# Score = (train: 0.051, test: 0.496)
# Score = (train: 0.229, test: 0.711)
# Score = (train: 0.050, test: 0.477)
# Score = (train: 0.051, test: 0.463)
# ---4: 58---
#   --- Sem classificação
# Score = (train: 0.227, test: 0.280)
# Score = (train: 0.216, test: 0.412)
# Score = (train: 0.062, test: 0.466)
# Score = (train: 0.246, test: 0.333)
# Score = (train: 0.222, test: 0.351)
#   --- Com classificação
# Score = (train: 0.051, test: 0.496)
# Score = (train: 0.215, test: 0.291)
# Score = (train: 0.207, test: 0.469)
# Score = (train: 0.057, test: 0.478)
# Score = (train: 0.218, test: 0.546)
# ---5: 69---
#   --- Sem classificação
# Score = (train: 0.229, test: 0.482)
# Score = (train: 0.056, test: 0.470)
# Score = (train: 0.051, test: 0.484)
# Score = (train: 0.226, test: 0.198)
# Score = (train: 0.193, test: 0.406)
#   --- Com classificação
# Score = (train: 0.060, test: 0.481)
# Score = (train: 0.210, test: 0.415)
# Score = (train: 0.213, test: 0.571)
# Score = (train: 0.059, test: 0.473)
# Score = (train: 0.060, test: 0.474)
# ---6: 78---
#   --- Sem classificação
# Score = (train: 0.237, test: 0.391)
# Score = (train: 0.227, test: 0.391)
# Score = (train: 0.220, test: 0.438)
# Score = (train: 0.221, test: 0.463)
# Score = (train: 0.219, test: 0.497)
#   --- Com classificação
# Score = (train: 0.058, test: 0.467)
# Score = (train: 0.052, test: 0.500)
# Score = (train: 0.201, test: 0.458)
# Score = (train: 0.248, test: 0.457)
# Score = (train: 0.055, test: 0.456)
# ---7: 88---
#   --- Sem classificação
# Score = (train: 0.062, test: 0.452)
# Score = (train: 0.221, test: 0.479)
# Score = (train: 0.053, test: 0.507)
# Score = (train: 0.264, test: 0.522)
# Score = (train: 0.053, test: 0.513)
#   --- Com classificação
# Score = (train: 0.048, test: 0.504)
# Score = (train: 0.048, test: 0.492)
# Score = (train: 0.234, test: 0.274)
# Score = (train: 0.148, test: 0.772)
# Score = (train: 0.224, test: 0.431)
# ---8: 98---
#   --- Sem classificação
# Score = (train: 0.056, test: 0.461)
# Score = (train: 0.241, test: 0.225)
# Score = (train: 0.195, test: 0.447)
# Score = (train: 0.054, test: 0.473)
# Score = (train: 0.234, test: 0.278)
#   --- Com classificação
# Score = (train: 0.209, test: 0.544)
# Score = (train: 0.062, test: 0.452)
# Score = (train: 0.218, test: 0.441)
# Score = (train: 0.186, test: 0.631)
# Score = (train: 0.229, test: 0.305)
# ---9: 105---
#   --- Sem classificação
# Score = (train: 0.207, test: 0.413)
# Score = (train: 0.175, test: 0.567)
# Score = (train: 0.218, test: 0.396)
# Score = (train: 0.252, test: 0.274)
# Score = (train: 0.053, test: 0.499)
#   --- Com classificação
# Score = (train: 0.255, test: 0.291)
# Score = (train: 0.228, test: 0.384)
# Score = (train: 0.179, test: 0.428)
# Score = (train: 0.057, test: 0.461)
# Score = (train: 0.051, test: 0.510)
# ---10: 110---
#   --- Sem classificação
# Score = (train: 0.051, test: 0.501)
# Score = (train: 0.233, test: 0.272)
# Score = (train: 0.202, test: 0.574)
# Score = (train: 0.202, test: 0.357)
# Score = (train: 0.062, test: 0.454)
#   --- Com classificação
# Score = (train: 0.053, test: 0.506)
# Score = (train: 0.056, test: 0.469)
# Score = (train: 0.252, test: 0.264)
# Score = (train: 0.058, test: 0.492)
# Score = (train: 0.217, test: 0.697)

# %%
def plot_erros(saida_dados):
    x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 = saida_dados

    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 4))

    ax1.set_title('Sem Classificação CVM')
    ax1.errorbar([ np.mean(i) for i in x ], [ np.mean(i) for i in y_train_1 ], yerr=[ np.std(i) for i in y_train_1 ], fmt='o', c='tab:orange', label='Treino')
    ax1.errorbar([ np.mean(i) for i in x ], [ np.mean(i) for i in y_test_1 ], yerr=[ np.std(i) for i in y_test_1 ], fmt='o', c='tab:blue', label='Teste')
    ax1.hlines(0.01, np.min([ np.mean(i) for i in x ]), np.max([ np.mean(i) for i in x ]), colors='tab:green', label='Ideal: 0.01')
    ax1.set_xlabel('Quantidade de variavéis')
    ax1.set_ylabel('MAE')
    ax1.set_ylim((1e-3, 100))
    ax1.set_yscale('log')
    ax1.legend(loc='best')

    ax2.set_title('Com Classificação CVM')
    ax2.errorbar([ np.mean(i) for i in x ], [ np.mean(i) for i in y_train_2 ], yerr=[ np.std(i) for i in y_train_2 ], fmt='o', c='tab:red', label='Treino')
    ax2.errorbar([ np.mean(i) for i in x ], [ np.mean(i) for i in y_test_2 ], yerr=[ np.std(i) for i in y_test_2 ], fmt='o', c='tab:green', label='Teste')
    ax2.hlines(0.01, np.min([ np.mean(i) for i in x ]), np.max([ np.mean(i) for i in x ]), colors='tab:green', label='Ideal: 0.01')
    ax2.set_xlabel('Quantidade de variavéis')
    ax2.set_ylabel('MAE')
    ax2.set_ylim((1e-3, 100))
    ax2.set_yscale('log')
    ax2.legend(loc='best')

    ax3.set_title('Valores dentro do esperado')
    ax3.scatter([ np.mean(i) for i in x ], [ 100*np.sum(np.abs(np.asarray(i)) <= 0.01)/np.asarray(i).size for i in error_test_1 ], c='tab:blue')
    ax3.scatter([ np.mean(i) for i in x ], [ 100*np.sum(np.abs(np.asarray(i)) <= 0.01)/np.asarray(i).size for i in error_train_1 ], c='tab:orange')
    ax3.scatter([ np.mean(i) for i in x ], [ 100*np.sum(np.abs(np.asarray(i)) <= 0.01)/np.asarray(i).size for i in error_test_2 ], c='tab:green')
    ax3.scatter([ np.mean(i) for i in x ], [ 100*np.sum(np.abs(np.asarray(i)) <= 0.01)/np.asarray(i).size for i in error_train_2 ], c='tab:red')
    ax3.set_xlabel('Quantidade de variavéis')
    ax3.set_ylabel('Porcentagem de valores ideais (%)')
    ax3.set_ylim((0, 25))
    
    
    plt.show()

# %%
plot_erros(saida_dados_12)

# %%
plot_erros(saida_dados_24)

# %%
plot_erros(saida_dados_36)

# %%
plot_erros(saida_dados_48)

# %%
plot_erros(saida_dados_60)

# %%
plot_erros(saida_dados_72)
