# %%
import numpy as np
import pandas as pd
import xarray as xr
import urllib.request
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
#list_metricas = ['average_clustering', 'coefficient_distribution_degree', 'density', 'average_degree', 'average_short_path']#, 'number_of_nodes']
list_metricas = ['average_clustering', 'coefficient_distribution_degree', 'density', 'average_degree']

list_variables_a = [
    #'Patrimonio_Liquido',
    #'Cotas_Emitidas',
    #'Valor_Patrimonial_Cotas',
    'Percentual_Rentabilidade_Efetiva_Mes',
    'Percentual_Rentabilidade_Patrimonial_Mes',
    #'Percentual_Dividend_Yield_Mes',
    #'Percentual_Amortizacao_Cotas_Mes',
]


list_variables_b = [
    'Valor_Ativo',
    'Percentual_Despesas_Taxa_Administracao',
    'Percentual_Despesas_Agente_Custodiante',
    'Total_Necessidades_Liquidez',
    'Disponibilidades',
    'Titulos_Publicos',
    'Titulos_Privados',
    'Fundos_Renda_Fixa',
    'Total_Investido',
    'Direitos_Bens_Imoveis',
    'Terrenos',
    'Imoveis_Renda_Acabados',
    'Imoveis_Renda_Construcao',
    'Imoveis_Venda_Acabados',
    'Imoveis_Venda_Construcao',
    'Outros_Direitos_Reais',
    'Acoes',
    #'Debentures',
    #'Bonus_Subscricao',
    'Certificados_Deposito_Valores_Mobiliarios',
    #'Cedulas_Debentures',
    #'Fundo_Acoes',
    #'FIP',
    'FII',
    #'FDIC',
    'Outras_Cotas_FI',
    #'Notas_Promissorias',
    'Acoes_Sociedades_Atividades_FII',
    'Cotas_Sociedades_Atividades_FII',
    'CEPAC',
    'CRI',
    #'Letras_Hipotecarias',
    #'LCI',
    #'LIG',
    'Outros_Valores_Mobliarios',
    'Valores_Receber',
    'Contas_Receber_Aluguel',
    'Contas_Receber_Venda_Imoveis',
    'Outros_Valores_Receber',
    'Rendimentos_Distribuir',
    'Taxa_Administracao_Pagar',
    'Taxa_Performance_Pagar',
    'Obrigacoes_Aquisicao_Imoveis',
    #'Adiantamento_Venda_Imoveis',
    'Adiantamento_Alugueis',
    'Obrigacoes_Securitizacao_Recebiveis',
    #'Instrumentos_Financeiros_Derivativos',
    'Provisoes_Contigencias',
    'Outros_Valores_Pagar',
    'Total_Passivo',
 ]

list_variables = list_variables_a + list_variables_b

list_cat = [
    #'Mandato',
    #'Segmento_Atuacao',
    #'Publico_Alvo',
    #'Tipo_Gestao',
]

ds_fii = xr.open_dataset('dataset/cvm/dataset_cvm_metrica_mensal.nc').fillna(0)
df_dados_fii = pd.read_csv('dataset/cvm/dataset_cvm_metrica_mensal_dados.csv', index_col='CNPJ_Fundo')

df_fii = ds_fii.to_array().stack(var=['variable', 'metrica']).to_pandas()

df_fii[['TIR']] = df_dados_fii[['TIR']][df_dados_fii[['TIR']].fillna(0).apply(zscore).abs() <= 1].fillna(0)
df_fii[[ (v, 'coefficient_distribution_degree') for v in list_variables ]] = df_fii[[ (v, 'coefficient_distribution_degree') for v in list_variables ]][df_fii[[ (v, 'coefficient_distribution_degree') for v in list_variables ]].apply(zscore).abs() <= 1].fillna(0)
df_fii_cat =  df_dados_fii[list_cat]


cnpj_meses = xr.open_dataset('dataset/cvm/dataset_cvm_metrica_mensal.nc').fillna(0).Acoes.sel(metrica='number_of_nodes').to_pandas()

# %%
def dataset_filter(df, lista_variaveis, lista_metricas, lista_cnpj):
    cols = [ (v, m) for v in lista_variaveis for m in lista_metricas ] + [ ('TIR', '') ]
    df_out = df[df.index.isin(lista_cnpj)][ cols ]
    
    return df_out.drop(columns=[ ('TIR', '') ]), df_out[ [ ('TIR', '') ] ]

# %%
def select_cols(df_fii, numbers, corr_val = 0.5, list_cat = []):
    grupos_fiis = df_dados_fii[list_cat].dropna().agg('-'.join, axis=1)

    set_cols = set()

    for grupo in np.unique(grupos_fiis.values):
        cnpj_grupo = grupos_fiis[grupos_fiis==grupo].index.values


        df_dados = df_fii[df_fii.index.isin(cnpj_grupo)]
        corr = df_dados.corr()
        cols = corr['TIR'][corr['TIR'].abs() >= corr_val].abs().sort_values(ascending=False).index.values[1:(numbers+1)]

        for t in cols:
            set_cols.add(t)

    set_cols.discard(('TIR', ''))
    return list(set_cols)

# %%
import copy

import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Resultado 1
#
# Gráfico por classificação

# %%
def model(X, y):
    from sklearn.ensemble import GradientBoostingRegressor
    from sklearn.neural_network import MLPRegressor
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.metrics import mean_absolute_error
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=2/3)
    
    best_score_train = np.inf
    best_score_test = np.inf
    best_weights = None
    
    for i in range(1, 6):
        model_train = MLPRegressor(max_iter=5000)
        model_train.fit(X_train, y_train)

        y_pred = model_train.predict(X_train)
        score_train = mean_absolute_error(y_train, y_pred)
        error_train = list(y_train-y_pred)

        y_pred = model_train.predict(X_test)
        score_test = mean_absolute_error(y_test, y_pred)
        error_test = list(y_test-y_pred)

        if score_test < best_score_test:
            best_score_test = score_test
            best_score_train = score_train
            best_error_test = error_test
            best_error_train = error_train
            best_weights = model_train.get_params()
    
    print(f'Score = (train: {best_score_train:.3f}, test: {best_score_test:.3f})')
    return best_score_train, best_score_test, best_weights, best_error_train, best_error_test

# %%
tamanho_series = 48

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(1):
    cols_corr = select_cols(df_fii_corr, 500, 0.0, [])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_48 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 157---
#   --- Sem classificação
# Score = (train: 0.063, test: 0.569)
# Score = (train: 0.039, test: 0.620)
# Score = (train: 0.115, test: 0.686)
# Score = (train: 0.114, test: 0.573)
# Score = (train: 0.067, test: 0.497)
#   --- Com classificação
# Score = (train: 0.059, test: 0.571)
# Score = (train: 0.065, test: 0.710)
# Score = (train: 0.211, test: 0.529)
# Score = (train: 0.073, test: 0.757)
# Score = (train: 0.072, test: 0.751)

# %%
tamanho_series = 24

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_24 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 24---
#   --- Sem classificação
# Score = (train: 0.224, test: 0.406)
# Score = (train: 0.087, test: 0.681)
# Score = (train: 0.306, test: 0.700)
# Score = (train: 0.303, test: 0.538)
# Score = (train: 0.267, test: 0.704)
#   --- Com classificação
# Score = (train: 0.300, test: 0.686)
# Score = (train: 0.305, test: 0.494)
# Score = (train: 0.261, test: 0.532)
# Score = (train: 0.080, test: 0.682)
# Score = (train: 0.141, test: 0.607)
# ---2: 45---
#   --- Sem classificação
# Score = (train: 0.301, test: 0.756)
# Score = (train: 0.226, test: 0.999)
# Score = (train: 0.244, test: 0.993)
# Score = (train: 0.148, test: 0.650)
# Score = (train: 0.335, test: 0.419)
#   --- Com classificação
# Score = (train: 0.300, test: 0.451)
# Score = (train: 0.220, test: 0.645)
# Score = (train: 0.279, test: 0.576)
# Score = (train: 0.198, test: 0.746)
# Score = (train: 0.146, test: 0.673)
# ---3: 62---
#   --- Sem classificação
# Score = (train: 0.273, test: 0.470)
# Score = (train: 0.250, test: 0.594)
# Score = (train: 0.256, test: 0.435)
# Score = (train: 0.135, test: 0.645)
# Score = (train: 0.244, test: 0.502)
#   --- Com classificação
# Score = (train: 0.155, test: 0.639)
# Score = (train: 0.333, test: 0.517)
# Score = (train: 0.128, test: 0.809)
# Score = (train: 0.241, test: 0.512)
# Score = (train: 0.294, test: 0.525)
# ---4: 77---
#   --- Sem classificação
# Score = (train: 0.282, test: 0.487)
# Score = (train: 0.234, test: 0.548)
# Score = (train: 0.153, test: 0.620)
# Score = (train: 0.169, test: 0.577)
# Score = (train: 0.255, test: 0.637)
#   --- Com classificação
# Score = (train: 0.260, test: 0.399)
# Score = (train: 0.217, test: 0.638)
# Score = (train: 0.231, test: 0.563)
# Score = (train: 0.149, test: 0.658)
# Score = (train: 0.093, test: 0.658)
# ---5: 91---
#   --- Sem classificação
# Score = (train: 0.320, test: 0.599)
# Score = (train: 0.325, test: 0.263)
# Score = (train: 0.320, test: 0.523)
# Score = (train: 0.256, test: 0.483)
# Score = (train: 0.228, test: 0.515)
#   --- Com classificação
# Score = (train: 0.360, test: 0.342)
# Score = (train: 0.303, test: 0.712)
# Score = (train: 0.094, test: 0.635)
# Score = (train: 0.291, test: 0.557)
# Score = (train: 0.217, test: 0.493)
# ---6: 102---
#   --- Sem classificação
# Score = (train: 0.292, test: 0.416)
# Score = (train: 0.273, test: 0.653)
# Score = (train: 0.317, test: 0.662)
# Score = (train: 0.291, test: 0.498)
# Score = (train: 0.323, test: 0.414)
#   --- Com classificação
# Score = (train: 0.262, test: 0.638)
# Score = (train: 0.290, test: 1.162)
# Score = (train: 0.149, test: 0.587)
# Score = (train: 0.079, test: 0.667)
# Score = (train: 0.089, test: 0.680)
# ---7: 111---
#   --- Sem classificação
# Score = (train: 0.311, test: 0.343)
# Score = (train: 0.079, test: 0.677)
# Score = (train: 0.277, test: 0.626)
# Score = (train: 0.150, test: 0.581)
# Score = (train: 0.293, test: 0.396)
#   --- Com classificação
# Score = (train: 0.317, test: 0.475)
# Score = (train: 0.135, test: 0.618)
# Score = (train: 0.217, test: 0.946)
# Score = (train: 0.213, test: 0.671)
# Score = (train: 0.261, test: 0.611)
# ---8: 117---
#   --- Sem classificação
# Score = (train: 0.227, test: 0.745)
# Score = (train: 0.254, test: 0.410)
# Score = (train: 0.250, test: 0.533)
# Score = (train: 0.311, test: 0.554)
# Score = (train: 0.251, test: 0.954)
#   --- Com classificação
# Score = (train: 0.300, test: 0.475)
# Score = (train: 0.148, test: 0.642)
# Score = (train: 0.283, test: 0.882)
# Score = (train: 0.341, test: 0.549)
# Score = (train: 0.143, test: 0.594)
# ---9: 124---
#   --- Sem classificação
# Score = (train: 0.289, test: 0.515)
# Score = (train: 0.323, test: 0.358)
# Score = (train: 0.303, test: 0.876)
# Score = (train: 0.284, test: 0.653)
# Score = (train: 0.315, test: 0.453)
#   --- Com classificação
# Score = (train: 0.079, test: 0.670)
# Score = (train: 0.072, test: 0.678)
# Score = (train: 0.303, test: 0.483)
# Score = (train: 0.281, test: 0.663)
# Score = (train: 0.264, test: 0.575)
# ---10: 126---
#   --- Sem classificação
# Score = (train: 0.144, test: 0.657)
# Score = (train: 0.309, test: 0.461)
# Score = (train: 0.299, test: 0.444)
# Score = (train: 0.235, test: 0.957)
# Score = (train: 0.256, test: 0.589)
#   --- Com classificação
# Score = (train: 0.275, test: 0.604)
# Score = (train: 0.342, test: 0.345)
# Score = (train: 0.252, test: 0.506)
# Score = (train: 0.246, test: 0.714)
# Score = (train: 0.151, test: 0.605)

# %%
tamanho_series = 36

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_36 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 18---
#   --- Sem classificação
# Score = (train: 0.070, test: 0.399)
# Score = (train: 0.146, test: 0.201)
# Score = (train: 0.139, test: 0.416)
# Score = (train: 0.126, test: 0.351)
# Score = (train: 0.079, test: 0.362)
#   --- Com classificação
# Score = (train: 0.082, test: 0.371)
# Score = (train: 0.163, test: 0.291)
# Score = (train: 0.076, test: 0.399)
# Score = (train: 0.129, test: 0.388)
# Score = (train: 0.159, test: 0.317)
# ---2: 29---
#   --- Sem classificação
# Score = (train: 0.149, test: 0.287)
# Score = (train: 0.089, test: 0.381)
# Score = (train: 0.149, test: 0.246)
# Score = (train: 0.148, test: 0.273)
# Score = (train: 0.143, test: 0.333)
#   --- Com classificação
# Score = (train: 0.076, test: 0.391)
# Score = (train: 0.133, test: 0.293)
# Score = (train: 0.078, test: 0.390)
# Score = (train: 0.073, test: 0.377)
# Score = (train: 0.149, test: 0.289)
# ---3: 43---
#   --- Sem classificação
# Score = (train: 0.082, test: 0.369)
# Score = (train: 0.152, test: 0.303)
# Score = (train: 0.140, test: 0.774)
# Score = (train: 0.154, test: 0.345)
# Score = (train: 0.146, test: 0.273)
#   --- Com classificação
# Score = (train: 0.137, test: 0.268)
# Score = (train: 0.151, test: 0.330)
# Score = (train: 0.075, test: 0.397)
# Score = (train: 0.087, test: 0.363)
# Score = (train: 0.168, test: 0.248)
# ---4: 57---
#   --- Sem classificação
# Score = (train: 0.136, test: 0.283)
# Score = (train: 0.145, test: 0.270)
# Score = (train: 0.082, test: 0.380)
# Score = (train: 0.152, test: 0.270)
# Score = (train: 0.150, test: 0.278)
#   --- Com classificação
# Score = (train: 0.148, test: 0.281)
# Score = (train: 0.160, test: 0.423)
# Score = (train: 0.083, test: 0.375)
# Score = (train: 0.157, test: 0.272)
# Score = (train: 0.156, test: 0.254)
# ---5: 71---
#   --- Sem classificação
# Score = (train: 0.160, test: 0.326)
# Score = (train: 0.091, test: 0.362)
# Score = (train: 0.142, test: 0.637)
# Score = (train: 0.159, test: 0.388)
# Score = (train: 0.074, test: 0.371)
#   --- Com classificação
# Score = (train: 0.173, test: 0.305)
# Score = (train: 0.174, test: 0.282)
# Score = (train: 0.166, test: 0.252)
# Score = (train: 0.159, test: 0.327)
# Score = (train: 0.171, test: 0.392)
# ---6: 81---
#   --- Sem classificação
# Score = (train: 0.078, test: 0.387)
# Score = (train: 0.133, test: 0.563)
# Score = (train: 0.166, test: 0.303)
# Score = (train: 0.071, test: 0.381)
# Score = (train: 0.161, test: 0.371)
#   --- Com classificação
# Score = (train: 0.166, test: 0.341)
# Score = (train: 0.155, test: 0.500)
# Score = (train: 0.074, test: 0.366)
# Score = (train: 0.176, test: 0.289)
# Score = (train: 0.075, test: 0.404)
# ---7: 91---
#   --- Sem classificação
# Score = (train: 0.172, test: 0.394)
# Score = (train: 0.160, test: 0.404)
# Score = (train: 0.168, test: 0.335)
# Score = (train: 0.162, test: 0.336)
# Score = (train: 0.167, test: 0.236)
#   --- Com classificação
# Score = (train: 0.149, test: 0.379)
# Score = (train: 0.131, test: 0.401)
# Score = (train: 0.175, test: 0.317)
# Score = (train: 0.163, test: 0.277)
# Score = (train: 0.071, test: 0.380)
# ---8: 100---
#   --- Sem classificação
# Score = (train: 0.160, test: 0.331)
# Score = (train: 0.175, test: 0.363)
# Score = (train: 0.160, test: 0.394)
# Score = (train: 0.163, test: 0.379)
# Score = (train: 0.151, test: 0.314)
#   --- Com classificação
# Score = (train: 0.166, test: 0.448)
# Score = (train: 0.170, test: 0.304)
# Score = (train: 0.155, test: 0.597)
# Score = (train: 0.156, test: 0.262)
# Score = (train: 0.183, test: 0.296)
# ---9: 106---
#   --- Sem classificação
# Score = (train: 0.159, test: 0.352)
# Score = (train: 0.150, test: 0.298)
# Score = (train: 0.165, test: 0.283)
# Score = (train: 0.076, test: 0.415)
# Score = (train: 0.185, test: 0.260)
#   --- Com classificação
# Score = (train: 0.076, test: 0.356)
# Score = (train: 0.080, test: 0.392)
# Score = (train: 0.076, test: 0.363)
# Score = (train: 0.147, test: 0.473)
# Score = (train: 0.087, test: 0.364)
# ---10: 115---
#   --- Sem classificação
# Score = (train: 0.165, test: 0.291)
# Score = (train: 0.168, test: 0.299)
# Score = (train: 0.086, test: 0.382)
# Score = (train: 0.081, test: 0.352)
# Score = (train: 0.171, test: 0.291)
#   --- Com classificação
# Score = (train: 0.081, test: 0.350)
# Score = (train: 0.158, test: 0.475)
# Score = (train: 0.170, test: 0.247)
# Score = (train: 0.162, test: 0.304)
# Score = (train: 0.166, test: 0.299)

# %%
tamanho_series = 48

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_48 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 19---
#   --- Sem classificação
# Score = (train: 0.148, test: 0.273)
# Score = (train: 0.151, test: 0.179)
# Score = (train: 0.142, test: 0.487)
# Score = (train: 0.192, test: 0.456)
# Score = (train: 0.169, test: 0.567)
#   --- Com classificação
# Score = (train: 0.063, test: 0.436)
# Score = (train: 0.149, test: 0.238)
# Score = (train: 0.157, test: 0.297)
# Score = (train: 0.151, test: 0.259)
# Score = (train: 0.173, test: 0.279)
# ---2: 32---
#   --- Sem classificação
# Score = (train: 0.142, test: 0.317)
# Score = (train: 0.143, test: 0.332)
# Score = (train: 0.127, test: 0.236)
# Score = (train: 0.150, test: 0.340)
# Score = (train: 0.149, test: 0.449)
#   --- Com classificação
# Score = (train: 0.171, test: 0.237)
# Score = (train: 0.153, test: 0.408)
# Score = (train: 0.171, test: 0.210)
# Score = (train: 0.158, test: 0.301)
# Score = (train: 0.147, test: 0.446)
# ---3: 45---
#   --- Sem classificação
# Score = (train: 0.073, test: 0.391)
# Score = (train: 0.080, test: 0.375)
# Score = (train: 0.059, test: 0.434)
# Score = (train: 0.158, test: 0.333)
# Score = (train: 0.076, test: 0.379)
#   --- Com classificação
# Score = (train: 0.080, test: 0.384)
# Score = (train: 0.073, test: 0.406)
# Score = (train: 0.073, test: 0.393)
# Score = (train: 0.176, test: 0.232)
# Score = (train: 0.065, test: 0.414)
# ---4: 59---
#   --- Sem classificação
# Score = (train: 0.073, test: 0.406)
# Score = (train: 0.187, test: 0.276)
# Score = (train: 0.066, test: 0.423)
# Score = (train: 0.066, test: 0.413)
# Score = (train: 0.168, test: 0.349)
#   --- Com classificação
# Score = (train: 0.176, test: 0.321)
# Score = (train: 0.167, test: 0.307)
# Score = (train: 0.178, test: 0.554)
# Score = (train: 0.187, test: 0.242)
# Score = (train: 0.063, test: 0.414)
# ---5: 66---
#   --- Sem classificação
# Score = (train: 0.199, test: 0.400)
# Score = (train: 0.167, test: 0.391)
# Score = (train: 0.081, test: 0.374)
# Score = (train: 0.089, test: 0.369)
# Score = (train: 0.201, test: 0.232)
#   --- Com classificação
# Score = (train: 0.171, test: 0.434)
# Score = (train: 0.068, test: 0.420)
# Score = (train: 0.072, test: 0.401)
# Score = (train: 0.184, test: 0.322)
# Score = (train: 0.208, test: 0.416)
# ---6: 77---
#   --- Sem classificação
# Score = (train: 0.076, test: 0.395)
# Score = (train: 0.196, test: 0.364)
# Score = (train: 0.181, test: 0.241)
# Score = (train: 0.198, test: 0.353)
# Score = (train: 0.199, test: 0.204)
#   --- Com classificação
# Score = (train: 0.071, test: 0.422)
# Score = (train: 0.173, test: 0.320)
# Score = (train: 0.075, test: 0.395)
# Score = (train: 0.181, test: 0.243)
# Score = (train: 0.060, test: 0.447)
# ---7: 89---
#   --- Sem classificação
# Score = (train: 0.182, test: 0.373)
# Score = (train: 0.194, test: 0.387)
# Score = (train: 0.070, test: 0.394)
# Score = (train: 0.199, test: 0.312)
# Score = (train: 0.069, test: 0.428)
#   --- Com classificação
# Score = (train: 0.165, test: 0.288)
# Score = (train: 0.172, test: 0.454)
# Score = (train: 0.073, test: 0.414)
# Score = (train: 0.178, test: 0.436)
# Score = (train: 0.182, test: 0.310)
# ---8: 98---
#   --- Sem classificação
# Score = (train: 0.068, test: 0.424)
# Score = (train: 0.191, test: 0.370)
# Score = (train: 0.076, test: 0.407)
# Score = (train: 0.191, test: 0.683)
# Score = (train: 0.157, test: 0.496)
#   --- Com classificação
# Score = (train: 0.205, test: 0.254)
# Score = (train: 0.160, test: 0.531)
# Score = (train: 0.179, test: 0.303)
# Score = (train: 0.174, test: 0.272)
# Score = (train: 0.054, test: 0.459)
# ---9: 106---
#   --- Sem classificação
# Score = (train: 0.073, test: 0.394)
# Score = (train: 0.075, test: 0.422)
# Score = (train: 0.062, test: 0.422)
# Score = (train: 0.178, test: 0.269)
# Score = (train: 0.139, test: 0.704)
#   --- Com classificação
# Score = (train: 0.187, test: 0.327)
# Score = (train: 0.191, test: 0.228)
# Score = (train: 0.066, test: 0.437)
# Score = (train: 0.071, test: 0.404)
# Score = (train: 0.202, test: 0.246)
# ---10: 112---
#   --- Sem classificação
# Score = (train: 0.179, test: 0.306)
# Score = (train: 0.068, test: 0.411)
# Score = (train: 0.183, test: 0.246)
# Score = (train: 0.190, test: 0.391)
# Score = (train: 0.160, test: 0.461)
#   --- Com classificação
# Score = (train: 0.188, test: 0.329)
# Score = (train: 0.068, test: 0.395)
# Score = (train: 0.195, test: 0.307)
# Score = (train: 0.178, test: 0.549)
# Score = (train: 0.181, test: 0.511)

# %%
tamanho_series = 60

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)


saida_dados_60 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 19---
#   --- Sem classificação
# Score = (train: 0.208, test: 0.320)
# Score = (train: 0.215, test: 0.508)
# Score = (train: 0.184, test: 0.594)
# Score = (train: 0.223, test: 0.416)
# Score = (train: 0.056, test: 0.410)
#   --- Com classificação
# Score = (train: 0.240, test: 0.339)
# Score = (train: 0.223, test: 0.433)
# Score = (train: 0.194, test: 0.592)
# Score = (train: 0.047, test: 0.433)
# Score = (train: 0.052, test: 0.413)
# ---2: 35---
#   --- Sem classificação
# Score = (train: 0.240, test: 0.583)
# Score = (train: 0.212, test: 0.416)
# Score = (train: 0.229, test: 0.384)
# Score = (train: 0.226, test: 0.376)
# Score = (train: 0.051, test: 0.399)
#   --- Com classificação
# Score = (train: 0.053, test: 0.416)
# Score = (train: 0.206, test: 0.427)
# Score = (train: 0.043, test: 0.470)
# Score = (train: 0.229, test: 0.622)
# Score = (train: 0.228, test: 0.398)
# ---3: 50---
#   --- Sem classificação
# Score = (train: 0.237, test: 0.333)
# Score = (train: 0.187, test: 0.368)
# Score = (train: 0.051, test: 0.424)
# Score = (train: 0.213, test: 0.327)
# Score = (train: 0.199, test: 0.530)
#   --- Com classificação
# Score = (train: 0.053, test: 0.403)
# Score = (train: 0.218, test: 0.490)
# Score = (train: 0.051, test: 0.425)
# Score = (train: 0.201, test: 0.363)
# Score = (train: 0.203, test: 0.366)
# ---4: 62---
#   --- Sem classificação
# Score = (train: 0.171, test: 0.197)
# Score = (train: 0.163, test: 0.319)
# Score = (train: 0.051, test: 0.419)
# Score = (train: 0.166, test: 0.190)
# Score = (train: 0.046, test: 0.426)
#   --- Com classificação
# Score = (train: 0.048, test: 0.431)
# Score = (train: 0.170, test: 0.189)
# Score = (train: 0.168, test: 0.323)
# Score = (train: 0.050, test: 0.422)
# Score = (train: 0.159, test: 0.272)
# ---5: 73---
#   --- Sem classificação
# Score = (train: 0.166, test: 0.482)
# Score = (train: 0.059, test: 0.398)
# Score = (train: 0.165, test: 0.311)
# Score = (train: 0.191, test: 0.319)
# Score = (train: 0.044, test: 0.432)
#   --- Com classificação
# Score = (train: 0.169, test: 0.349)
# Score = (train: 0.178, test: 0.291)
# Score = (train: 0.060, test: 0.391)
# Score = (train: 0.198, test: 0.289)
# Score = (train: 0.202, test: 0.249)
# ---6: 81---
#   --- Sem classificação
# Score = (train: 0.059, test: 0.397)
# Score = (train: 0.204, test: 0.329)
# Score = (train: 0.204, test: 0.171)
# Score = (train: 0.196, test: 0.445)
# Score = (train: 0.051, test: 0.431)
#   --- Com classificação
# Score = (train: 0.054, test: 0.419)
# Score = (train: 0.047, test: 0.444)
# Score = (train: 0.045, test: 0.436)
# Score = (train: 0.190, test: 0.448)
# Score = (train: 0.053, test: 0.408)
# ---7: 88---
#   --- Sem classificação
# Score = (train: 0.055, test: 0.432)
# Score = (train: 0.048, test: 0.437)
# Score = (train: 0.184, test: 0.342)
# Score = (train: 0.055, test: 0.432)
# Score = (train: 0.174, test: 0.483)
#   --- Com classificação
# Score = (train: 0.192, test: 0.445)
# Score = (train: 0.053, test: 0.422)
# Score = (train: 0.060, test: 0.414)
# Score = (train: 0.198, test: 0.439)
# Score = (train: 0.052, test: 0.425)
# ---8: 96---
#   --- Sem classificação
# Score = (train: 0.211, test: 0.367)
# Score = (train: 0.052, test: 0.416)
# Score = (train: 0.203, test: 0.418)
# Score = (train: 0.191, test: 0.342)
# Score = (train: 0.198, test: 0.308)
#   --- Com classificação
# Score = (train: 0.056, test: 0.395)
# Score = (train: 0.193, test: 0.511)
# Score = (train: 0.182, test: 0.393)
# Score = (train: 0.194, test: 0.346)
# Score = (train: 0.229, test: 0.190)
# ---9: 101---
#   --- Sem classificação
# Score = (train: 0.209, test: 0.235)
# Score = (train: 0.055, test: 0.416)
# Score = (train: 0.184, test: 0.419)
# Score = (train: 0.050, test: 0.430)
# Score = (train: 0.191, test: 0.663)
#   --- Com classificação
# Score = (train: 0.048, test: 0.425)
# Score = (train: 0.189, test: 0.382)
# Score = (train: 0.052, test: 0.436)
# Score = (train: 0.208, test: 0.353)
# Score = (train: 0.205, test: 0.447)
# ---10: 106---
#   --- Sem classificação
# Score = (train: 0.186, test: 0.458)
# Score = (train: 0.196, test: 0.479)
# Score = (train: 0.180, test: 0.309)
# Score = (train: 0.183, test: 0.571)
# Score = (train: 0.173, test: 0.494)
#   --- Com classificação
# Score = (train: 0.059, test: 0.424)
# Score = (train: 0.179, test: 0.672)
# Score = (train: 0.191, test: 0.427)
# Score = (train: 0.196, test: 0.485)
# Score = (train: 0.050, test: 0.419)

# %%
tamanho_series = 72

num_test = 5


list_cnpj = cnpj_meses[cnpj_meses >= tamanho_series].index.values
df_fii_feature, df_fii_target = dataset_filter(df_fii, list_variables, list_metricas, list_cnpj)
df_fii_corr = pd.merge(df_fii_feature, df_fii_target, left_index=True, right_index=True)


preprocessing = OneHotEncoder().fit_transform(df_fii_cat[df_fii_cat.index.isin(df_fii_feature.index.values)]).toarray()

#cols_corr = select_cols(df_fii_corr, 50, 0.0, [])

x = []
y_train_1 = []
y_test_1 = []
weights_1 = []
error_train_1 = []
error_test_1 = []
y_train_2 = []
y_test_2 = []
weights_2 = []
error_train_2 = []
error_test_2 = []

for i in range(10):
    cols_corr = select_cols(df_fii_corr, i+1, 0.5, ['Mandato', 'Segmento_Atuacao'])
    x.append(len(cols_corr))

    print(f'---{i+1}: {len(cols_corr)}---')

    target = df_fii_target.values.flatten()
    features = df_fii_feature[cols_corr].values

    print(f'  --- Sem classificação')
    y_train_1_i = []
    y_test_1_i = []
    weights_1_i = []
    error_train_1_i = []
    error_test_1_i = []

    for _ in range(num_test):
        X, y = features, target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_1_i.append(best_score_train)
        y_test_1_i.append(best_score_test)
        weights_1_i.append(best_weights)
        error_train_1_i.append(error_train)
        error_test_1_i.append(error_test)

    y_train_1.append(y_train_1_i)
    y_test_1.append(y_test_1_i)
    weights_1.append(weights_1_i)
    error_train_1.append(error_train_1_i)
    error_test_1.append(error_test_1_i)


    print(f'  --- Com classificação')
    y_train_2_i = []
    y_test_2_i = []
    weights_2_i = []
    error_train_2_i = []
    error_test_2_i = []

    for _ in range(num_test):
        X, y = np.hstack( (features, preprocessing) ), target
        best_score_train, best_score_test, best_weights, error_train, error_test = model(X, y)

        y_train_2_i.append(best_score_train)
        y_test_2_i.append(best_score_test)
        weights_2_i.append(best_weights)
        error_train_2_i.append(error_train)
        error_test_2_i.append(error_test)

    y_train_2.append(y_train_2_i)
    y_test_2.append(y_test_2_i)
    weights_2.append(weights_2_i)
    error_train_2.append(error_train_2_i)
    error_test_2.append(error_test_2_i)

saida_dados_72 = [ x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 ]
# Out:
# ---1: 19---
#   --- Sem classificação
# Score = (train: 0.054, test: 0.486)
# Score = (train: 0.231, test: 0.283)
# Score = (train: 0.056, test: 0.482)
# Score = (train: 0.208, test: 0.651)
# Score = (train: 0.215, test: 0.394)
#   --- Com classificação
# Score = (train: 0.053, test: 0.485)
# Score = (train: 0.049, test: 0.505)
# Score = (train: 0.043, test: 0.509)
# Score = (train: 0.059, test: 0.469)
# Score = (train: 0.224, test: 0.583)
# ---2: 33---
#   --- Sem classificação
# Score = (train: 0.199, test: 0.340)
# Score = (train: 0.200, test: 0.328)
# Score = (train: 0.182, test: 0.247)
# Score = (train: 0.197, test: 0.237)
# Score = (train: 0.181, test: 0.376)
#   --- Com classificação
# Score = (train: 0.055, test: 0.481)
# Score = (train: 0.200, test: 0.276)
# Score = (train: 0.221, test: 0.175)
# Score = (train: 0.195, test: 0.422)
# Score = (train: 0.048, test: 0.489)
# ---3: 43---
#   --- Sem classificação
# Score = (train: 0.044, test: 0.523)
# Score = (train: 0.056, test: 0.464)
# Score = (train: 0.060, test: 0.439)
# Score = (train: 0.195, test: 0.305)
# Score = (train: 0.232, test: 0.266)
#   --- Com classificação
# Score = (train: 0.194, test: 0.265)
# Score = (train: 0.221, test: 0.372)
# Score = (train: 0.205, test: 0.432)
# Score = (train: 0.211, test: 0.336)
# Score = (train: 0.204, test: 0.257)
# ---4: 58---
#   --- Sem classificação
# Score = (train: 0.053, test: 0.473)
# Score = (train: 0.217, test: 0.266)
# Score = (train: 0.206, test: 0.463)
# Score = (train: 0.054, test: 0.484)
# Score = (train: 0.159, test: 0.815)
#   --- Com classificação
# Score = (train: 0.234, test: 0.263)
# Score = (train: 0.180, test: 0.330)
# Score = (train: 0.171, test: 0.413)
# Score = (train: 0.210, test: 0.297)
# Score = (train: 0.188, test: 0.420)
# ---5: 69---
#   --- Sem classificação
# Score = (train: 0.214, test: 0.501)
# Score = (train: 0.048, test: 0.494)
# Score = (train: 0.204, test: 0.228)
# Score = (train: 0.221, test: 0.560)
# Score = (train: 0.200, test: 0.931)
#   --- Com classificação
# Score = (train: 0.231, test: 0.444)
# Score = (train: 0.053, test: 0.489)
# Score = (train: 0.187, test: 0.633)
# Score = (train: 0.221, test: 0.467)
# Score = (train: 0.231, test: 0.336)
# ---6: 78---
#   --- Sem classificação
# Score = (train: 0.206, test: 0.314)
# Score = (train: 0.226, test: 0.534)
# Score = (train: 0.213, test: 0.313)
# Score = (train: 0.225, test: 0.410)
# Score = (train: 0.055, test: 0.460)
#   --- Com classificação
# Score = (train: 0.236, test: 0.519)
# Score = (train: 0.162, test: 0.800)
# Score = (train: 0.242, test: 0.682)
# Score = (train: 0.049, test: 0.485)
# Score = (train: 0.238, test: 0.272)
# ---7: 88---
#   --- Sem classificação
# Score = (train: 0.225, test: 0.543)
# Score = (train: 0.241, test: 0.241)
# Score = (train: 0.244, test: 0.313)
# Score = (train: 0.251, test: 0.203)
# Score = (train: 0.213, test: 0.286)
#   --- Com classificação
# Score = (train: 0.229, test: 0.313)
# Score = (train: 0.178, test: 0.393)
# Score = (train: 0.062, test: 0.457)
# Score = (train: 0.056, test: 0.462)
# Score = (train: 0.214, test: 0.581)
# ---8: 98---
#   --- Sem classificação
# Score = (train: 0.221, test: 0.487)
# Score = (train: 0.251, test: 0.183)
# Score = (train: 0.232, test: 0.530)
# Score = (train: 0.253, test: 0.218)
# Score = (train: 0.221, test: 0.349)
#   --- Com classificação
# Score = (train: 0.168, test: 0.682)
# Score = (train: 0.218, test: 0.277)
# Score = (train: 0.047, test: 0.509)
# Score = (train: 0.237, test: 0.375)
# Score = (train: 0.222, test: 0.407)
# ---9: 105---
#   --- Sem classificação
# Score = (train: 0.197, test: 0.617)
# Score = (train: 0.239, test: 0.566)
# Score = (train: 0.201, test: 0.311)
# Score = (train: 0.052, test: 0.478)
# Score = (train: 0.051, test: 0.485)
#   --- Com classificação
# Score = (train: 0.244, test: 0.414)
# Score = (train: 0.051, test: 0.494)
# Score = (train: 0.060, test: 0.476)
# Score = (train: 0.209, test: 0.316)
# Score = (train: 0.224, test: 0.238)
# ---10: 110---
#   --- Sem classificação
# Score = (train: 0.232, test: 0.296)
# Score = (train: 0.209, test: 0.592)
# Score = (train: 0.212, test: 0.484)
# Score = (train: 0.182, test: 0.563)
# Score = (train: 0.182, test: 0.656)
#   --- Com classificação
# Score = (train: 0.062, test: 0.474)
# Score = (train: 0.066, test: 0.448)
# Score = (train: 0.223, test: 0.373)
# Score = (train: 0.232, test: 0.236)
# Score = (train: 0.053, test: 0.479)

# %%
def plot_erros(saida_dados):
    x, y_train_1, y_test_1, weights_1, error_train_1, error_test_1, y_train_2, y_test_2, weights_2, error_train_2, error_test_2 = saida_dados

    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 4))

    ax1.set_title('Sem Classificação CVM')
    ax1.errorbar([ np.mean(i) for i in x ], [ np.mean(i) for i in y_train_1 ], yerr=[ np.std(i) for i in y_train_1 ], fmt='o', c='tab:orange', label='Treino')
    ax1.errorbar([ np.mean(i) for i in x ], [ np.mean(i) for i in y_test_1 ], yerr=[ np.std(i) for i in y_test_1 ], fmt='o', c='tab:blue', label='Teste')
    ax1.hlines(0.01, np.min([ np.mean(i) for i in x ]), np.max([ np.mean(i) for i in x ]), colors='tab:green', label='Ideal: 0.01')
    ax1.set_xlabel('Quantidade de variavéis')
    ax1.set_ylabel('MAE')
    ax1.set_ylim((1e-3, 100))
    ax1.set_yscale('log')
    ax1.legend(loc='best')

    ax2.set_title('Com Classificação CVM')
    ax2.errorbar([ np.mean(i) for i in x ], [ np.mean(i) for i in y_train_2 ], yerr=[ np.std(i) for i in y_train_2 ], fmt='o', c='tab:red', label='Treino')
    ax2.errorbar([ np.mean(i) for i in x ], [ np.mean(i) for i in y_test_2 ], yerr=[ np.std(i) for i in y_test_2 ], fmt='o', c='tab:green', label='Teste')
    ax2.hlines(0.01, np.min([ np.mean(i) for i in x ]), np.max([ np.mean(i) for i in x ]), colors='tab:green', label='Ideal: 0.01')
    ax2.set_xlabel('Quantidade de variavéis')
    ax2.set_ylabel('MAE')
    ax2.set_ylim((1e-3, 100))
    ax2.set_yscale('log')
    ax2.legend(loc='best')

    ax3.set_title('Valores dentro do esperado')
    ax3.scatter([ np.mean(i) for i in x ], [ 100*np.sum(np.abs(np.asarray(i)) <= 0.01)/np.asarray(i).size for i in error_test_1 ], c='tab:blue')
    ax3.scatter([ np.mean(i) for i in x ], [ 100*np.sum(np.abs(np.asarray(i)) <= 0.01)/np.asarray(i).size for i in error_train_1 ], c='tab:orange')
    ax3.scatter([ np.mean(i) for i in x ], [ 100*np.sum(np.abs(np.asarray(i)) <= 0.01)/np.asarray(i).size for i in error_test_2 ], c='tab:green')
    ax3.scatter([ np.mean(i) for i in x ], [ 100*np.sum(np.abs(np.asarray(i)) <= 0.01)/np.asarray(i).size for i in error_train_2 ], c='tab:red')
    ax3.set_xlabel('Quantidade de variavéis')
    ax3.set_ylabel('Porcentagem de valores ideais (%)')
    ax3.set_ylim((0, 25))
    
    
    plt.show()

# %%
plot_erros(saida_dados_12)

# %%
plot_erros(saida_dados_24)

# %%
plot_erros(saida_dados_36)

# %%
plot_erros(saida_dados_48)

# %%
plot_erros(saida_dados_60)

# %%
plot_erros(saida_dados_72)
