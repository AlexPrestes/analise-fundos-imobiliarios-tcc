# %%
from analise_fundos_imobiliarios.run import *

# %%
ds = transform_files_cvm_mensal()

# %%
ds['CEPAC'].sum(axis=1)[ds['CEPAC'].sum(axis=1) != 0]
# Out:
# <xarray.DataArray 'CEPAC' (CNPJ_Fundo: 4)>
# array([2.67842160e+05, 4.09730094e+09, 3.98469092e+11, 9.25000000e+05])
# Coordinates:
#   * CNPJ_Fundo  (CNPJ_Fundo) object '08.610.522/0001-17' ... '19.419.994/0001...

# %%
ds['LCI'].sum(axis=1)[ds['LCI'].sum(axis=1) != 0]
# Out:
# <xarray.DataArray 'LCI' (CNPJ_Fundo: 81)>
# array([3.06546197e+09, 5.20862507e+08, 6.62390902e+08, 4.12667789e+09,
#        6.78605633e+08, 3.01291111e+08, 1.02155518e+09, 1.00691914e+07,
#        1.44438201e+09, 2.09495787e+08, 1.37759872e+08, 7.59521769e+08,
#        5.20838352e+08, 1.29228134e+09, 1.38079288e+10, 2.75015229e+09,
#        3.95601962e+08, 5.44824653e+09, 2.59304293e+08, 6.79516119e+08,
#        3.91118828e+07, 2.42625350e+09, 4.16285987e+08, 5.55926910e+08,
#        7.65791168e+08, 9.64017493e+06, 3.45039003e+09, 9.70353170e+05,
#        5.72690718e+09, 1.72156966e+06, 1.74004312e+08, 3.21401462e+08,
#        2.78411108e+09, 7.04854166e+06, 3.50234187e+07, 3.08250604e+07,
#        6.03713508e+07, 4.43157271e+09, 2.78300724e+08, 4.00626175e+09,
#        1.50159239e+08, 2.05311933e+08, 3.50234187e+07, 1.57841825e+07,
#        7.96081594e+08, 9.55413285e+08, 1.50215394e+08, 1.38282769e+08,
#        1.51147095e+07, 1.66607487e+07, 1.58191844e+08, 1.14871381e+08,
# ...

# %%
ds['FDIC'].sum(axis=1)[ds['FDIC'].sum(axis=1) != 0]
# Out:
# <xarray.DataArray 'FDIC' (CNPJ_Fundo: 21)>
# array([2.51997962e+07, 2.50000000e+07, 2.47800307e+06, 1.84047769e+07,
#        5.16834957e+07, 1.26964145e+08, 1.80684634e+08, 8.80592799e+08,
#        3.55323791e+07, 8.43487587e+08, 1.85756234e+07, 1.08770554e+08,
#        1.56198214e+07, 4.85306605e+07, 8.75214132e+07, 1.10563746e+08,
#        7.46476539e+07, 1.91456822e+08, 9.39741773e+07, 5.78536345e+07,
#        4.78499665e+07])
# Coordinates:
#   * CNPJ_Fundo  (CNPJ_Fundo) object '14.631.148/0001-39' ... '44.625.826/0001...

# %%
ds['LIG'].sum(axis=1)[ds['LIG'].sum(axis=1) != 0]
# Out:
# <xarray.DataArray 'LIG' (CNPJ_Fundo: 0)>
# array([], dtype=float64)
# Coordinates:
#   * CNPJ_Fundo  (CNPJ_Fundo) object
